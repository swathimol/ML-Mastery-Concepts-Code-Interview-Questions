# %% [markdown]
# [data](https://docs.google.com/spreadsheets/d/1VW7ODXlF51KS7IAdNYL2Bt3W1ShB5Wqzo1nCZOSCRZU/edit?usp=sharing)

# %% [markdown]
# **1. Data Cleaning (15 points)**
# * Handle missing values: Fill using mean/median/mode or drop rows/columns if necessary.
# * Remove duplicates: Ensure data integrity by eliminating duplicate entries.
# * Handle outliers: Use IQR or Z-score to detect and treat outliers.
# * Standardize categorical values: Fix inconsistencies (e.g., "Male"/"M"/"male").
#
#
#
# **2. Data Exploration (15 points)**
# * Statistical summary: Use `.describe()` for an overview of the dataset.
# * Check for correlations: Use a heatmap to find highly correlated features.
# * Visualize distributions: Use histograms, boxplots, and KDE plots.
# * Identify patterns and trends: Use scatter plots and line charts.
# * Analyze class balance: Check if the target variable is imbalanced.
#
# **3. Feature Engineering (15 points)**
# * Encoding categorical variables: Apply One-Hot or Label Encoding.
# * Create new features: Generate meaningful features based on domain knowledge.
# * Feature transformation: Apply log/square transformations for skewed distributions.
# * Feature scaling: Normalize/standardize numerical features.
#
# **4. Model Selection (10 points)**
# * Choose appropriate models: Classification or regression, based on the problem.
# * Baseline model: Start with a simple model (e.g., Logistic Regression).
#
# **5. Model Training with Training Data (10 points)**
# * Split dataset: Train-test split (e.g., 80%-20%).
# * Train the model: Fit the selected model using training data.
# * Evaluate training performance: Use accuracy, RMSE, or AUC.
# * Save the trained model: Store for future predictions.
#
# **6. Optimizing the Model (5 points)**
# * Hyperparameter tuning: Use `GridSearchCV` or `RandomizedSearchCV`.
# * Regularization: Apply L1/L2 to prevent overfitting.
# * Feature selection: Remove unimportant features.
# * Ensemble techniques: Consider bagging, boosting, or stacking.
#
# **7. Prediction with Test Data (10 points)**
# * Preprocess test data: Apply same transformations as training data.
# * Make predictions: Use the trained model on test data.
# * Evaluate predictions: Check accuracy, precision, recall, RMSE, or F1-score.
#
# **8. Output Saving (10 points)**
# * Save predictions: Store results in a CSV or database.
# * Save model: Use `joblib.dump()` or `pickle` to save the trained model.
#
#
# **9. Test Case Result (10 points)**
# * Test with new data: Validate using unseen data.

# %%
import pandas as pd

# %%
data=pd.read_csv("/content/coda.csv")
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# ### 📌 What is the Dataset About?
# This dataset likely contains customer information from a telecom company, including details about their subscription, charges, services, and churn status.
# Goal: Analyze the factors affecting customer churn (whether a customer leaves or stays).

# %% [markdown]
# 📌 Features in the Dataset
# Here are the columns (features) and their meanings:
#
# | Feature Name        | Data Type | Description |
# |---------------------|----------|-------------|
# | **gender**         | Object   | Customer gender (Male/Female) |
# | **SeniorCitizen**  | Integer  | Whether the customer is a senior citizen (1 = Yes, 0 = No) |
# | **Partner**        | Object   | Whether the customer has a partner (Yes/No) |
# | **Dependents**     | Object   | Whether the customer has dependents (Yes/No) |
# | **tenure**         | Integer  | Number of months the customer has stayed |
# | **PhoneService**   | Object   | Whether the customer has phone service (Yes/No) |
# | **MultipleLines**  | Object   | Whether the customer has multiple lines (Yes/No/No Phone Service) |
# | **InternetService**| Object   | Type of internet service (DSL, Fiber optic, No) |
# | **OnlineSecurity** | Object   | Whether the customer has online security service (Yes/No) |
# | **OnlineBackup**   | Object   | Whether the customer has online backup service (Yes/No) |
# | **DeviceProtection**| Object  | Whether the customer has device protection (Yes/No) |
# | **TechSupport**    | Object   | Whether the customer has tech support (Yes/No) |
# | **StreamingTV**    | Object   | Whether the customer has streaming TV service (Yes/No) |
# | **StreamingMovies**| Object   | Whether the customer has streaming movies service (Yes/No) |
# | **Contract**       | Object   | Type of contract (Month-to-month, One year, Two years) |
# | **PaperlessBilling**| Object  | Whether billing is paperless (Yes/No) |
# | **PaymentMethod**  | Object   | Payment method (Electronic check, Mailed check, Bank transfer, Credit card) |
# | **MonthlyCharges** | Float    | The amount charged to the customer monthly |
# | **TotalCharges**   | Float    | The total amount charged to the customer |
# | **Churn**         | Object   | Whether the customer churned (Yes/No) (Target Variable) |

# %%
train_data = data.sample(frac=0.8, random_state=42)  # 80% of data

# %%
train_data=data.sample()

# %%
train_data =data.sample(frac=0.8,random_state=200)
test_data=data.drop(train_data.index)

# %% [markdown]
# # **1. Data Cleaning (15 points)**
# * Handle missing values: Fill using mean/median/mode or drop rows/columns if necessary.
# * Remove duplicates: Ensure data integrity by eliminating duplicate entries.
# * Handle outliers: Use IQR or Z-score to detect and treat outliers.
# * Standardize categorical values: Fix inconsistencies (e.g., "Male"/"M"/"male").
# * Feature transformation: Apply log/square transformations for skewed distributions.

# %%
train_data.shape
# Out:
# (5634, 21)

# %%
test_data.shape
# Out:
# (1409, 21)

# %% [markdown]
# information

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5634 entries, 2632 to 2270
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        5634 non-null   object
#  1   gender            5634 non-null   object
#  2   SeniorCitizen     5634 non-null   int64
#  3   Partner           5634 non-null   object
#  4   Dependents        5634 non-null   object
#  5   tenure            5634 non-null   int64
#  6   PhoneService      5634 non-null   object
#  7   MultipleLines     5634 non-null   object
#  8   InternetService   5634 non-null   object
#  9   OnlineSecurity    5629 non-null   object
#  10  OnlineBackup      5629 non-null   object
#  11  DeviceProtection  5629 non-null   object
#  12  TechSupport       5629 non-null   object
#  13  StreamingTV       5629 non-null   object
#  14  StreamingMovies   5629 non-null   object
#  15  Contract          5634 non-null   object
# ...

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1409 entries, 2 to 7033
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        1409 non-null   object
#  1   gender            1409 non-null   object
#  2   SeniorCitizen     1409 non-null   int64
#  3   Partner           1409 non-null   object
#  4   Dependents        1409 non-null   object
#  5   tenure            1409 non-null   int64
#  6   PhoneService      1409 non-null   object
#  7   MultipleLines     1409 non-null   object
#  8   InternetService   1409 non-null   object
#  9   OnlineSecurity    1409 non-null   object
#  10  OnlineBackup      1409 non-null   object
#  11  DeviceProtection  1409 non-null   object
#  12  TechSupport       1409 non-null   object
#  13  StreamingTV       1409 non-null   object
#  14  StreamingMovies   1409 non-null   object
#  15  Contract          1409 non-null   object
# ...

# %% [markdown]
# describe

# %%
train_data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    5634.000000  5634.000000     5634.000000
# mean        0.161697    32.251154       64.824485
# std         0.368205    24.612991       30.074669
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.750000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.887500
# max         1.000000    72.000000      118.750000

# %%
test_data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    1409.000000  1409.000000     1409.000000
# mean        0.163946    32.850958       64.510610
# std         0.370358    24.347110       30.160845
# min         0.000000     0.000000       18.700000
# 25%         0.000000    10.000000       34.650000
# 50%         0.000000    30.000000       70.300000
# 75%         0.000000    56.000000       89.750000
# max         1.000000    72.000000      118.600000

# %% [markdown]
# missing

# %%
train_data.isnull().mean() *100
# Out:
# customerID           0.000000
# gender               0.000000
# SeniorCitizen        0.000000
# Partner              0.000000
# Dependents           0.000000
# tenure               0.000000
# PhoneService         0.000000
# MultipleLines        0.000000
# InternetService      0.000000
# OnlineSecurity       0.088747
# OnlineBackup         0.088747
# DeviceProtection     0.088747
# TechSupport          0.088747
# StreamingTV          0.088747
# StreamingMovies      0.088747
# Contract             0.000000
# PaperlessBilling     0.000000
# PaymentMethod        0.053248
# MonthlyCharges       0.000000
# TotalCharges        26.446574
# Churn                0.000000
# dtype: float64

# %%
for column in train_data.columns:
  print(column)
# Out:
# customerID
# gender
# SeniorCitizen
# Partner
# Dependents
# tenure
# PhoneService
# MultipleLines
# InternetService
# OnlineSecurity
# OnlineBackup
# DeviceProtection
# TechSupport
# StreamingTV
# StreamingMovies
# Contract
# PaperlessBilling
# PaymentMethod
# MonthlyCharges
# TotalCharges
# Churn

# %%
# Handle missing values using imputation
for column in train_data.columns:
    if train_data[column].dtype == 'object':  # For categorical variables
        train_data[column].fillna(train_data[column].mode()[0], inplace=True)
        test_data[column].fillna(test_data[column].mode()[0], inplace=True)
    else:  # For numerical variables
        train_data[column].fillna(train_data[column].median(), inplace=True)
        test_data[column].fillna(test_data[column].median(), inplace=True)
# Out:
# <ipython-input-86-d2e86a94c13c>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_data[column].fillna(train_data[column].mode()[0], inplace=True)
# <ipython-input-86-d2e86a94c13c>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
train_data.isnull().mean()
# Out:
# customerID          0.0
# gender              0.0
# SeniorCitizen       0.0
# Partner             0.0
# Dependents          0.0
# tenure              0.0
# PhoneService        0.0
# MultipleLines       0.0
# InternetService     0.0
# OnlineSecurity      0.0
# OnlineBackup        0.0
# DeviceProtection    0.0
# TechSupport         0.0
# StreamingTV         0.0
# StreamingMovies     0.0
# Contract            0.0
# PaperlessBilling    0.0
# PaymentMethod       0.0
# MonthlyCharges      0.0
# TotalCharges        0.0
# Churn               0.0
# dtype: float64

# %%
test_data.isnull().mean()
# Out:
# customerID          0.0
# gender              0.0
# SeniorCitizen       0.0
# Partner             0.0
# Dependents          0.0
# tenure              0.0
# PhoneService        0.0
# MultipleLines       0.0
# InternetService     0.0
# OnlineSecurity      0.0
# OnlineBackup        0.0
# DeviceProtection    0.0
# TechSupport         0.0
# StreamingTV         0.0
# StreamingMovies     0.0
# Contract            0.0
# PaperlessBilling    0.0
# PaymentMethod       0.0
# MonthlyCharges      0.0
# TotalCharges        0.0
# Churn               0.0
# dtype: float64

# %% [markdown]
# step:1 missing values handled

# %%
train_data.duplicated().sum()
# Out:
# 0

# %%
test_data.duplicated().sum()
# Out:
# 0

# %%
# Remove duplicates
train_data.drop_duplicates(inplace=True)
test_data.drop_duplicates(inplace=True)

# %%
# step2: no duplicates

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(data=train_data)
plt.show()

# %%
sns.boxplot(data=test_data)
plt.show()

# %%
def handle_outliers(df, columns):
    for column in columns:
        if df[column].dtype in ['float64', 'int64']:
            Q1 = df[column].quantile(0.25)  # 1st quartile
            Q3 = df[column].quantile(0.75)  # 3rd quartile
            IQR = Q3 - Q1
            lower_bound = Q1 - 1.5 * IQR
            upper_bound = Q3 + 1.5 * IQR
            # Clip the outliers
            df[column] = df[column].clip(lower_bound, upper_bound)
    return df
train_data = handle_outliers(train_data, train_data.columns)

# %%
train_data = handle_outliers(train_data, train_data.columns)

# %%
test_data = handle_outliers(test_data, test_data.columns)

# %%
sns.boxplot(data=train_data)
plt.show()

# %%
sns.boxplot(data=test_data)
plt.show()

# %%
train_data.select_dtypes("number").skew()
# Out:
# SeniorCitizen     0.000000
# tenure            0.245312
# MonthlyCharges   -0.221984
# dtype: float64

# %%
test_data.select_dtypes("number").skew()
# Out:
# SeniorCitizen     0.000000
# tenure            0.217377
# MonthlyCharges   -0.214859
# dtype: float64

# %%
import numpy as np

# Compute skewness
skewness = train_data.select_dtypes("number").skew()

# Apply transformations
for col in skewness.index:
    if skewness[col] > 0.5:  # Positively skewed
        train_data[col] = np.log1p(train_data[col])
        test_data[col] = np.log1p(test_data[col])
    elif skewness[col] < -0.5:  # Negatively skewed
        train_data[col] = np.square(train_data[col])
        test_data[col] = np.square(test_data[col])

print("Transformations applied to:", skewness[abs(skewness) > 0.5].index.tolist())
# Out:
# Transformations applied to: []

# %%
train_data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2632  9018-PCIOK  Female              0      No         No      55
# 1027  6732-FZUGP  Female              0      No         No      47
# 6123  0623-EJQEG    Male              0      No         No      65
# 6071  0401-WDBXM    Male              0     Yes        Yes      72
# 3136  3884-HCSWG  Female              0      No         No      17
# ...          ...     ...            ...     ...        ...     ...
# 2737  5074-FBGHB    Male              0      No         No      64
# 2896  9522-ZSINC    Male              0      No         No      13
# 1099  6921-OZMFH    Male              0     Yes        Yes       5
# 5179  9048-JVYVF    Male              0      No         No       3
# 2270  4140-MUHUG  Female              0      No         No       3
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 2632          Yes            No             DSL                   No  ...
# ...

# %%
# Standardize categorical values
train_data.replace({'Male': 'M', 'Female': 'F'}, inplace=True)
test_data.replace({'Male': 'M', 'Female': 'F'}, inplace=True)

# %%
train_data
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 2632  9018-PCIOK      F              0      No         No      55
# 1027  6732-FZUGP      F              0      No         No      47
# 6123  0623-EJQEG      M              0      No         No      65
# 6071  0401-WDBXM      M              0     Yes        Yes      72
# 3136  3884-HCSWG      F              0      No         No      17
# ...          ...    ...            ...     ...        ...     ...
# 2737  5074-FBGHB      M              0      No         No      64
# 2896  9522-ZSINC      M              0      No         No      13
# 1099  6921-OZMFH      M              0     Yes        Yes       5
# 5179  9048-JVYVF      M              0      No         No       3
# 2270  4140-MUHUG      F              0      No         No       3
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 2632          Yes            No             DSL                   No  ...
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5634 entries, 2632 to 2270
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        5634 non-null   object
#  1   gender            5634 non-null   object
#  2   SeniorCitizen     5634 non-null   int64
#  3   Partner           5634 non-null   object
#  4   Dependents        5634 non-null   object
#  5   tenure            5634 non-null   int64
#  6   PhoneService      5634 non-null   object
#  7   MultipleLines     5634 non-null   object
#  8   InternetService   5634 non-null   object
#  9   OnlineSecurity    5634 non-null   object
#  10  OnlineBackup      5634 non-null   object
#  11  DeviceProtection  5634 non-null   object
#  12  TechSupport       5634 non-null   object
#  13  StreamingTV       5634 non-null   object
#  14  StreamingMovies   5634 non-null   object
#  15  Contract          5634 non-null   object
# ...

# %%
train_data["TotalCharges"] = pd.to_numeric(train_data["TotalCharges"], errors='coerce')

train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5634 entries, 2632 to 2270
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        5634 non-null   object
#  1   gender            5634 non-null   object
#  2   SeniorCitizen     5634 non-null   int64
#  3   Partner           5634 non-null   object
#  4   Dependents        5634 non-null   object
#  5   tenure            5634 non-null   int64
#  6   PhoneService      5634 non-null   object
#  7   MultipleLines     5634 non-null   object
#  8   InternetService   5634 non-null   object
#  9   OnlineSecurity    5634 non-null   object
#  10  OnlineBackup      5634 non-null   object
#  11  DeviceProtection  5634 non-null   object
#  12  TechSupport       5634 non-null   object
#  13  StreamingTV       5634 non-null   object
#  14  StreamingMovies   5634 non-null   object
#  15  Contract          5634 non-null   object
# ...

# %%
train_data.dropna(inplace=True)

# %%
test_data["TotalCharges"] = pd.to_numeric(test_data["TotalCharges"], errors='coerce')

test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1409 entries, 2 to 7033
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        1409 non-null   object
#  1   gender            1409 non-null   object
#  2   SeniorCitizen     1409 non-null   int64
#  3   Partner           1409 non-null   object
#  4   Dependents        1409 non-null   object
#  5   tenure            1409 non-null   int64
#  6   PhoneService      1409 non-null   object
#  7   MultipleLines     1409 non-null   object
#  8   InternetService   1409 non-null   object
#  9   OnlineSecurity    1409 non-null   object
#  10  OnlineBackup      1409 non-null   object
#  11  DeviceProtection  1409 non-null   object
#  12  TechSupport       1409 non-null   object
#  13  StreamingTV       1409 non-null   object
#  14  StreamingMovies   1409 non-null   object
#  15  Contract          1409 non-null   object
# ...

# %%
test_data.dropna(inplace=True)
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1033 entries, 2 to 7033
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        1033 non-null   object
#  1   gender            1033 non-null   object
#  2   SeniorCitizen     1033 non-null   int64
#  3   Partner           1033 non-null   object
#  4   Dependents        1033 non-null   object
#  5   tenure            1033 non-null   int64
#  6   PhoneService      1033 non-null   object
#  7   MultipleLines     1033 non-null   object
#  8   InternetService   1033 non-null   object
#  9   OnlineSecurity    1033 non-null   object
#  10  OnlineBackup      1033 non-null   object
#  11  DeviceProtection  1033 non-null   object
#  12  TechSupport       1033 non-null   object
#  13  StreamingTV       1033 non-null   object
#  14  StreamingMovies   1033 non-null   object
#  15  Contract          1033 non-null   object
# ...

# %%
train_data.drop(["customerID"],axis=1,inplace=True)
test_data.drop(["customerID"],axis=1,inplace=True)

# %% [markdown]
# # **2. Data Exploration (15 points)**
# * Statistical summary: Use `.describe()` for an overview of the dataset.
# * Check for correlations: Use a heatmap to find highly correlated features.
# * Visualize distributions: Use histograms, boxplots, and KDE plots.
# * Identify patterns and trends: Use scatter plots and line charts.
# * Analyze class balance: Check if the target variable is imbalanced.

# %%
# Display summary statistics
train_data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count         5630.0  5630.000000     5630.000000   5630.000000
# mean             0.0    32.274067       64.842158   1682.019725
# std              0.0    24.606710       30.074343   2193.390090
# min              0.0     0.000000       18.250000     18.900000
# 25%              0.0     9.000000       35.750000     20.200000
# 50%              0.0    29.000000       70.350000    615.550000
# 75%              0.0    55.000000       89.900000   2647.000000
# max              0.0    72.000000      118.750000   8684.800000

# %%
train_data.drop("SeniorCitizen",axis=1,inplace=True)

# %%
test_data.drop("SeniorCitizen",axis=1,inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,4))
sns.countplot(x=data['Churn'], palette="coolwarm")
plt.title("Churn Distribution")
plt.xlabel("Churn")
plt.ylabel("Count")
plt.show()
# Out:
# <ipython-input-115-1e425d694292>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data['Churn'], palette="coolwarm")

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x=data['Churn'], y=data['MonthlyCharges'], palette="viridis")
plt.title("Monthly Charges vs Churn")
plt.xlabel("Churn")
plt.ylabel("Monthly Charges")
plt.show()
# Out:
# <ipython-input-116-ecdb84568117>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=data['Churn'], y=data['MonthlyCharges'], palette="viridis")

# %%
plt.figure(figsize=(8,5))
sns.histplot(data['tenure'], bins=30, kde=True, color='blue')
plt.title("Tenure Distribution")
plt.xlabel("Months")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="InternetService", hue="Churn", data=data, palette="Set2")
plt.title("Internet Service vs Churn")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x="Contract", hue="Churn", data=data, palette="coolwarm")
plt.title("Contract Type vs Churn")
plt.show()

# %%
plt.figure(figsize=(6,6))
data["Contract"].value_counts().plot(kind="pie", autopct='%1.1f%%', colors=["lightcoral", "gold", "lightblue"], startangle=140, wedgeprops={'edgecolor': 'black'})
plt.title("Contract Type Distribution")
plt.ylabel("")  # Hide y-label
plt.show()

# %% [markdown]
# # **3. Feature Engineering (15 points)**
# * Encoding categorical variables: Apply One-Hot or Label Encoding.
# * Create new features: Generate meaningful features based on domain knowledge.
#
# * Feature scaling: Normalize/standardize numerical features.

# %%
cat=train_data.select_dtypes("object")
cat
# Out:
#      gender Partner Dependents PhoneService MultipleLines InternetService  \
# 2632      F      No         No          Yes            No             DSL
# 1027      F      No         No          Yes           Yes     Fiber optic
# 6123      M      No         No          Yes           Yes     Fiber optic
# 6071      M     Yes        Yes          Yes           Yes     Fiber optic
# 3136      F      No         No          Yes            No     Fiber optic
# ...     ...     ...        ...          ...           ...             ...
# 2737      M      No         No          Yes           Yes     Fiber optic
# 2896      M      No         No          Yes            No              No
# 1099      M     Yes        Yes          Yes           Yes             DSL
# 5179      M      No         No          Yes            No             DSL
# 2270      F      No         No          Yes            No     Fiber optic
#
#            OnlineSecurity         OnlineBackup     DeviceProtection  \
# ...

# %%
for i in cat.columns:
  print(i)
  print(train_data[i].value_counts())
# Out:
# gender
# gender
# M    2848
# F    2782
# Name: count, dtype: int64
# Partner
# Partner
# No     2938
# Yes    2692
# Name: count, dtype: int64
# Dependents
# Dependents
# No     3977
# Yes    1653
# Name: count, dtype: int64
# PhoneService
# PhoneService
# Yes    5070
# No      560
# Name: count, dtype: int64
# MultipleLines
# MultipleLines
# No                  2704
# Yes                 2366
# No phone service     560
# Name: count, dtype: int64
# InternetService
# InternetService
# Fiber optic    2501
# DSL            1924
# No             1205
# Name: count, dtype: int64
# OnlineSecurity
# OnlineSecurity
# No                     2827
# Yes                    1603
# No internet service    1200
# Name: count, dtype: int64
# OnlineBackup
# OnlineBackup
# No                     2467
# Yes                    1963
# No internet service    1200
# Name: count, dtype: int64
# DeviceProtection
# DeviceProtection
# No                     2506
# Yes                    1924
# ...

# %%
train_data=pd.get_dummies(train_data,dtype=int,drop_first=True)
test_data=pd.get_dummies(test_data,dtype=int,drop_first=True)

# %%
# encode type 2:
# https://colab.research.google.com/drive/1pqgyud89kz_IybhLm-KRxRjwHVh4DB5I#scrollTo=fxQUMqnzCEys

# %%
train_data
# Out:
#       tenure  MonthlyCharges  TotalCharges  gender_M  Partner_Yes  \
# 2632      55           64.75       3617.10         0            0
# 1027      47           94.90         20.20         0            0
# 6123      65           93.55       6069.25         1            0
# 6071      72          105.55       7542.25         1            1
# 3136      17           70.00       1144.50         0            0
# ...      ...             ...           ...       ...          ...
# 2737      64          104.65       6889.80         1            0
# 2896      13           19.95        253.80         1            0
# 1099       5           55.70         20.20         1            1
# 5179       3           69.35        191.35         1            0
# 2270       3           86.85        220.95         0            0
#
#       Dependents_Yes  PhoneService_Yes  MultipleLines_No phone service  \
# 2632               0                 1                               0
# ...

# %% [markdown]
# # This is a classification problem. We need to ensure that the data is balanced. If it is not balanced, we need to apply techniques to balance it.

# %%
train_data["Churn_Yes"].value_counts()
# Out:
# Churn_Yes
# 0    4103
# 1    1527
# Name: count, dtype: int64

# %%
#Calculate Class Imbalance Ratio
maj_cls=train_data['Churn_Yes'].value_counts().max()
min_cls=train_data['Churn_Yes'].value_counts().min()
ratio=maj_cls/min_cls
print(f"Class Imbalance Ratio: {ratio:.2f}")
# Out:
# Class Imbalance Ratio: 2.69

# %% [markdown]
# A Class Imbalance Ratio of 2.69 means that one class (probably "No Churn") is 2.69 times more frequent than the other class (probably "Churn").

# %% [markdown]
# # note:
# 🛠 Techniques for Different Class Imbalance Ratios
# CIR Range	Handling Techniques
# 1.0 - 1.5 (Slight Imbalance)	- No major adjustments needed
# - Stratified Sampling in train-test split
# 1.5 - 3.0 (Moderate Imbalance)	-
# - SMOTE (Synthetic Minority Over-sampling Technique)
# 3.0 - 10.0 (High Imbalance)	- SMOTE or ADASYN
# > 10.0 (Extreme Imbalance)	- Hybrid Approach: Over-sampling + Under-sampling
# - Anomaly Detection Methods (One-Class SVM, Isolation Forest)

# %%
X_train=  train_data.drop("Churn_Yes",axis=1)
y_train=train_data["Churn_Yes"]

# %%
# its for extreme classes

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline
# Define moderate under-oversampling strategy
smote = SMOTE(sampling_strategy=0.5)  # Increase minority class to 50% of majority
under = RandomUnderSampler(sampling_strategy=0.7)  # Reduce majority class to 70% of its original size

# Combine in a pipeline
pipeline = Pipeline(steps=[('o', smote), ('u', under)])

# Apply resampling
X_train_resampled, y_train_resampled = pipeline.fit_resample(X_train, y_train)

# Check class distribution before and after resampling
from collections import Counter
print("Original class distribution:", Counter(y_train))
print("Resampled class distribution:", Counter(y_train_resampled))
# Out:
# Original class distribution: Counter({0: 4103, 1: 1527})
# Resampled class distribution: Counter({0: 2930, 1: 2051})

# %%
 y_train_resampled.value_counts()
# Out:
# Churn_Yes
# 0    2930
# 1    2051
# Name: count, dtype: int64

# %%
#Calculate Class Imbalance Ratio
maj_cls=y_train_resampled.value_counts().max()
min_cls=y_train_resampled.value_counts().min()
ratio=maj_cls/min_cls
print(f"Class Imbalance Ratio: {ratio:.2f}")
# Out:
# Class Imbalance Ratio: 1.43

# %% [markdown]
# A Class Imbalance Ratio of 1.43 indicates that one class is 1.43 times more frequent than the other. This is a moderate imbalance, and depending on the model, it may or may not affect performance significantly.

# %% [markdown]
# # **preprocessing is done. ML IS NEXT**

# %% [markdown]
# # TRAINDATA- X_train_resampled, y_train_resampled
# #TEST DATA-X TEST, Y TEST

# %% [markdown]
# #imp note: that train_data is now X_train_resampled, y_train_resampled and we have to split test data as well

# %%
X_test=test_data.drop("Churn_Yes",axis=1)#feature
y_test=test_data["Churn_Yes"]#target

# %%
x_train=train_data.drop("Churn_Yes",axis=1)
y_train=train_data["Churn_Yes"]

# %% [markdown]
# # **4. Model Selection (10 points)**
# * Choose appropriate models: Classification or regression, based on the problem.
# * Baseline model: Start with a simple model (e.g., Logistic Regression).

# %%
from sklearn.preprocessing import StandardScaler

# Initialize the scaler
scaler = StandardScaler()

# Fit and transform the training data
X_train_scaled = scaler.fit_transform(X_train_resampled)

# Transform the test data using the same scaler
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Initialize Logistic Regression model
log_reg = LogisticRegression()

# Train the model on the balanced dataset
log_reg.fit(X_train_scaled, y_train_resampled)

# Make predictions
y_pred = log_reg.predict(X_test_scaled)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"🔹 Accuracy: {accuracy:.4f}\n")

# Print Classification Report
print("🔹 Classification Report:\n", classification_report(y_test, y_pred))

# Print Confusion Matrix
print("🔹 Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# 🔹 Accuracy: 0.8006
#
# 🔹 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.83      0.86       785
#            1       0.57      0.70      0.63       248
#
#     accuracy                           0.80      1033
#    macro avg       0.73      0.77      0.75      1033
# weighted avg       0.82      0.80      0.81      1033
#
# 🔹 Confusion Matrix:
#  [[654 131]
#  [ 75 173]]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Initialize the Random Forest model
rf_model = RandomForestClassifier()

# Train the model
rf_model.fit(X_train_scaled, y_train_resampled)

# Make predictions
y_pred_rf = rf_model.predict(X_test_scaled)

# Evaluate the model
accuracy_rf = accuracy_score(y_test, y_pred_rf)
print(f"🔹 Random Forest Accuracy: {accuracy_rf:.4f}\n")

# Print Classification Report
print("🔹 Classification Report:\n", classification_report(y_test, y_pred_rf))

# Print Confusion Matrix
print("🔹 Confusion Matrix:\n", confusion_matrix(y_test, y_pred_rf))
# Out:
# 🔹 Random Forest Accuracy: 0.7822
#
# 🔹 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.85      0.86       785
#            1       0.54      0.58      0.56       248
#
#     accuracy                           0.78      1033
#    macro avg       0.70      0.71      0.71      1033
# weighted avg       0.79      0.78      0.78      1033
#
# 🔹 Confusion Matrix:
#  [[664 121]
#  [104 144]]

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Initialize the SVM model with an RBF kernel
svc_model = SVC()

# Train the model
svc_model.fit(X_train_scaled, y_train_resampled)

# Make predictions
y_pred_svc = svc_model.predict(X_test_scaled)

# Evaluate the model
accuracy_svc = accuracy_score(y_test, y_pred_svc)
print(f"🔹 SVM Accuracy: {accuracy_svc:.4f}\n")

# Print Classification Report
print("🔹 Classification Report:\n", classification_report(y_test, y_pred_svc))

# Print Confusion Matrix
print("🔹 Confusion Matrix:\n", confusion_matrix(y_test, y_pred_svc))
# Out:
# 🔹 SVM Accuracy: 0.7880
#
# 🔹 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.82      0.86       785
#            1       0.55      0.68      0.61       248
#
#     accuracy                           0.79      1033
#    macro avg       0.72      0.75      0.73      1033
# weighted avg       0.81      0.79      0.80      1033
#
# 🔹 Confusion Matrix:
#  [[646 139]
#  [ 80 168]]

# %% [markdown]
# **6. Optimizing the Model (5 points)**
# * Hyperparameter tuning: Use `GridSearchCV` or `RandomizedSearchCV`.
# * Regularization: Apply L1/L2 to prevent overfitting.
# * Feature selection: Remove unimportant features.
# * Ensemble techniques: Consider bagging, boosting, or stacking.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

# Define hyperparameter grid
param_grid = {
    'C': [0.01, 0.1, 1, 10],   # Regularization strength
    'penalty': ['l1', 'l2'],   # Regularization type
    'solver': ['liblinear']    # Suitable for small datasets & L1/L2 penalties
}

# Initialize Logistic Regression model
log_reg = LogisticRegression(random_state=42)

# Perform Grid Search
grid_search = GridSearchCV(log_reg, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train_scaled, y_train_resampled)

# Get best model
best_log_reg = grid_search.best_estimator_

# Print best parameters
print(f"🔹 Best Hyperparameters: {grid_search.best_params_}")

# Evaluate the model
y_pred_logreg = best_log_reg.predict(X_test_scaled)
accuracy_logreg = accuracy_score(y_test, y_pred_logreg)
print(f"🔹 Tuned Logistic Regression Accuracy: {accuracy_logreg:.4f}\n")

# Classification Report
print("🔹 Classification Report:\n", classification_report(y_test, y_pred_logreg))
# Out:
# 🔹 Best Hyperparameters: {'C': 1, 'penalty': 'l2', 'solver': 'liblinear'}
# 🔹 Tuned Logistic Regression Accuracy: 0.8006
#
# 🔹 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.83      0.86       785
#            1       0.57      0.70      0.63       248
#
#     accuracy                           0.80      1033
#    macro avg       0.73      0.77      0.75      1033
# weighted avg       0.82      0.80      0.81      1033

# %% [markdown]
# **7. Prediction with Test Data (10 points)**
# * Preprocess test data: Apply same transformations as training data.
# * Make predictions: Use the trained model on test data.
# * Evaluate predictions: Check accuracy, precision, recall, RMSE, or F1-score.

# %%
# 🔹 Predict on X_test_scaled
y_pred= model.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %% [markdown]
# **8. Output Saving (10 points)**
# * Save predictions: Store results in a CSV or database.
# * Save model: Use `joblib.dump()` or `pickle` to save the trained model.

# %%
import joblib

# Save the best model
joblib.dump(best_log_reg, "logistic_regression_model.pkl")

print("✅ Model saved successfully as 'logistic_regression_model.pkl'")
